% %% [markdown]
% ## Experiment 1: Threshold of SNr delay
%
% I will test the range of Str activation that enables delayed firing of SNr. First, I will find the minimal number of Str cells need to pass delay, and then test the delay property from minimum to maximum number of Str cells to ensure that latency distribution remains unchanged.

% %% [markdown]
% When 0% of Str cells are activated,

% %%
% Monte Carlo
spk_gp=[];
spk_snr=[];
spk_str=[];
Isyn_snr = [];

%Runs 20s simulation without any stimulus to measure steady-state values. 
g_gp2snr = BGdelayline_setinit('stimCellsPer',0,'I_exc_gp',60,'prob_syn_gp2snr',0.35); % initial conductance of gp to snr synapses 

for l = 1:10
%%Simulation
[Vm_gp,Vm_snr,Vm_str, Isyn_gp, Isyn_snr,fr_gp] = BGdelayline('stimCellsPer',0,'I_exc_gp',60,'prob_syn_gp2snr',0.35,'g_gp2snr_i',g_gp2snr);

spk_gp = [spk_gp; Vm_gp==15];
spk_snr = [spk_snr; Vm_snr==15];
spk_str = [spk_str; Vm_str==15];
Isyn_snr = [Isyn_snr ; Isnr];
end

%%Plot
figure
subplot(5,1,1)
plotRaster(spk_str);
title('Spike rater plots (5pA)')
ylabel('Str cells')
subplot(5,1,2)

plotRaster(spk_gp);
ylabel('GP cells')
subplot(5,1,4)

plotRaster(spk_snr);
ylabel('SNr cell')


binWidth_gp = 50; %ms

t_bar_gp = 1:binWidth_gp:length(spk_gp);
psth_gp = zeros(1,length(t_bar_gp));

for psth_i = 1:length(t_bar_gp)-1

    psth_gp(psth_i) = sum(sum(spk_gp(:,t_bar_gp(psth_i):(t_bar_gp(psth_i)+binWidth_gp-1))));

end

%fr_gp = mean(psth_gp(find(1<=t_bar_gp*0.0001<=3)))/(size(spk_gp,1)*(binWidth_gp*0.0001));
subplot(5,1,3)
bar(t_bar_gp*0.0001,psth_gp/(size(spk_gp,1)*(binWidth_gp*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('gp PSTH (spikes/s)')


binWidth_snr = 50; %ms
t_bar_snr = 1:binWidth_snr:length(spk_snr);
psth_snr = zeros(1,length(t_bar_snr));

for psth_j = 1:length(t_bar_snr)-1
psth_snr(psth_j) = sum(sum(spk_snr(:,t_bar_snr(psth_j):(t_bar_snr(psth_j)+binWidth_snr-1))));
end

subplot(5,1,5)
bar(t_bar_snr*0.0001,psth_snr/(size(spk_snr,1)*(binWidth_snr*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('snr PSTH (spikes/s)')
% Out:
% Elapsed time is 1.551651 seconds.
% Elapsed time is 1.564816 seconds.
% Elapsed time is 1.553100 seconds.
% Elapsed time is 1.433522 seconds.
% Elapsed time is 1.440140 seconds.
% Elapsed time is 1.409726 seconds.
% Elapsed time is 1.395185 seconds.
% Elapsed time is 1.435432 seconds.
% Elapsed time is 1.431601 seconds.
% Elapsed time is 1.583061 seconds.

% %%
figure
plot(Isyn_gp(1,:))
legend('gp')

figure
plot(Isyn_snr(1,:))
legend('snr')

figure
plot(fr_gp)
legend('fr gp')

% %% [markdown]
% There is no transimission of signals to GP and SNr.
%
% When 20% of cells are activated,

% %%
% Monte Carlo
spk_gp=[];
spk_snr=[];
spk_str=[];
Isyn_snr = [];

%Runs 20s simulation without any stimulus to measure steady-state values. 
g_gp2snr = BGdelayline_setinit('stimCellsPer',20,'I_exc_gp',60,'prob_syn_gp2snr',0.35); % initial conductance of gp to snr synapses 

for l = 1:10
%%Simulation
[Vm_gp,Vm_snr,Vm_str, Isyn_gp, Isnr] = BGdelayline('stimCellsPer',20,'I_exc_gp',60,'prob_syn_gp2snr',0.35,'g_gp2snr_i',g_gp2snr);

spk_gp = [spk_gp; Vm_gp==15];
spk_snr = [spk_snr; Vm_snr==15];
spk_str = [spk_str; Vm_str==15];
Isyn_snr = [Isyn_snr ; Isnr];
end

%%Plot
figure
subplot(5,1,1)
plotRaster(spk_str);
title('Spike rater plots (5pA)')
ylabel('Str cells')
subplot(5,1,2)

plotRaster(spk_gp);
ylabel('GP cells')
subplot(5,1,4)

plotRaster(spk_snr);
ylabel('SNr cell')


binWidth_gp = 50; %ms

t_bar_gp = 1:binWidth_gp:length(spk_gp);
psth_gp = zeros(1,length(t_bar_gp));

for psth_i = 1:length(t_bar_gp)-1

    psth_gp(psth_i) = sum(sum(spk_gp(:,t_bar_gp(psth_i):(t_bar_gp(psth_i)+binWidth_gp-1))));

end

fr_gp = mean(psth_gp(find(1<=t_bar_gp*0.0001<=3)))/(size(spk_gp,1)*(binWidth_gp*0.0001));
subplot(5,1,3)
bar(t_bar_gp*0.0001,psth_gp/(size(spk_gp,1)*(binWidth_gp*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('gp PSTH (spikes/s)')


binWidth_snr = 50; %ms
t_bar_snr = 1:binWidth_snr:length(spk_snr);
psth_snr = zeros(1,length(t_bar_snr));

for psth_j = 1:length(t_bar_snr)-1
psth_snr(psth_j) = sum(sum(spk_snr(:,t_bar_snr(psth_j):(t_bar_snr(psth_j)+binWidth_snr-1))));
end

subplot(5,1,5)
bar(t_bar_snr*0.0001,psth_snr/(size(spk_snr,1)*(binWidth_snr*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('snr PSTH (spikes/s)')


figure
plot(Isnr)
% Out:
% Elapsed time is 0.780824 seconds.
% Elapsed time is 0.857802 seconds.
% Elapsed time is 0.804867 seconds.
% Elapsed time is 0.836565 seconds.
% Elapsed time is 0.822449 seconds.
% Elapsed time is 0.779464 seconds.
% Elapsed time is 0.846761 seconds.
% Elapsed time is 0.841769 seconds.
% Elapsed time is 0.813217 seconds.
% Elapsed time is 0.852744 seconds.

% %% [markdown]
% The activation is not strong enough to inhibit firing of GP cells.
%
% Next, 50% of cells are activated

% %%
% Monte Carlo
spk_gp=[];
spk_snr=[];
spk_str=[];
Isyn_snr = [];

%Runs 20s simulation without any stimulus to measure steady-state values. 
g_gp2snr = BGdelayline_setinit('stimCellsPer',50,'I_exc_gp',60,'prob_syn_gp2snr',0.35); % initial conductance of gp to snr synapses 

for l = 1:10
%%Simulation
[Vm_gp,Vm_snr,Vm_str, Isyn_gp, Isnr] = BGdelayline('stimCellsPer',50,'I_exc_gp',60,'prob_syn_gp2snr',0.35,'g_gp2snr_i',g_gp2snr);

spk_gp = [spk_gp; Vm_gp==15];
spk_snr = [spk_snr; Vm_snr==15];
spk_str = [spk_str; Vm_str==15];
Isyn_snr = [Isyn_snr ; Isnr];
end

%%Plot
figure
subplot(5,1,1)
plotRaster(spk_str);
title('Spike rater plots (5pA)')
ylabel('Str cells')
subplot(5,1,2)

plotRaster(spk_gp);
ylabel('GP cells')
subplot(5,1,4)

plotRaster(spk_snr);
ylabel('SNr cell')


binWidth_gp = 50; %ms

t_bar_gp = 1:binWidth_gp:length(spk_gp);
psth_gp = zeros(1,length(t_bar_gp));

for psth_i = 1:length(t_bar_gp)-1

    psth_gp(psth_i) = sum(sum(spk_gp(:,t_bar_gp(psth_i):(t_bar_gp(psth_i)+binWidth_gp-1))));

end

fr_gp = mean(psth_gp(find(1<=t_bar_gp*0.0001<=3)))/(size(spk_gp,1)*(binWidth_gp*0.0001));
subplot(5,1,3)
bar(t_bar_gp*0.0001,psth_gp/(size(spk_gp,1)*(binWidth_gp*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('gp PSTH (spikes/s)')


binWidth_snr = 50; %ms
t_bar_snr = 1:binWidth_snr:length(spk_snr);
psth_snr = zeros(1,length(t_bar_snr));

for psth_j = 1:length(t_bar_snr)-1
psth_snr(psth_j) = sum(sum(spk_snr(:,t_bar_snr(psth_j):(t_bar_snr(psth_j)+binWidth_snr-1))));
end

subplot(5,1,5)
bar(t_bar_snr*0.0001,psth_snr/(size(spk_snr,1)*(binWidth_snr*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('snr PSTH (spikes/s)')


figure
plot(Isnr)
% Out:
% Elapsed time is 0.793629 seconds.
% Elapsed time is 0.825164 seconds.
% Elapsed time is 0.816811 seconds.
% Elapsed time is 0.847838 seconds.
% Elapsed time is 0.811761 seconds.
% Elapsed time is 0.879904 seconds.
% Elapsed time is 0.813940 seconds.
% Elapsed time is 0.826169 seconds.
% Elapsed time is 0.787226 seconds.
% Elapsed time is 0.798282 seconds.

% %% [markdown]
% For 60%,

% %%
% Monte Carlo
spk_gp=[];
spk_snr=[];
spk_str=[];
Isyn_snr = [];

%Runs 20s simulation without any stimulus to measure steady-state values. 
g_gp2snr = BGdelayline_setinit('stimCellsPer',100,'I_exc_gp',0.00006,'prob_syn_gp2snr',0.35); % initial conductance of gp to snr synapses 

% I_ext = 6 is the number that matches Vthr - Vrest

for l = 1:10
%%Simulation
[Vm_gp,Vm_snr,Vm_str, Isyn_gp, Isnr, fr_gp] = BGdelayline('stimCellsPer',100,'I_exc_gp',0.00006,'prob_syn_gp2snr',0.35,'g_gp2snr_i',g_gp2snr);

spk_gp = [spk_gp; Vm_gp==15];
spk_snr = [spk_snr; Vm_snr==15];
spk_str = [spk_str; Vm_str==15];
Isyn_snr = [Isyn_snr ; Isnr];
end

%%Plot
figure
subplot(5,1,1)
plotRaster(spk_str);
title('Spike rater plots (5pA)')
ylabel('Str cells')
subplot(5,1,2)

plotRaster(spk_gp);
ylabel('GP cells')
subplot(5,1,4)

plotRaster(spk_snr);
ylabel('SNr cell')


binWidth_gp = 50; %ms

t_bar_gp = 1:binWidth_gp:length(spk_gp);
psth_gp = zeros(1,length(t_bar_gp));

for psth_i = 1:length(t_bar_gp)-1

    psth_gp(psth_i) = sum(sum(spk_gp(:,t_bar_gp(psth_i):(t_bar_gp(psth_i)+binWidth_gp-1))));

end

fr_gp = mean(psth_gp(find(1<=t_bar_gp*0.0001<=3)))/(size(spk_gp,1)*(binWidth_gp*0.0001));
subplot(5,1,3)
bar(t_bar_gp*0.0001,psth_gp/(size(spk_gp,1)*(binWidth_gp*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('gp PSTH (spikes/s)')


binWidth_snr = 50; %ms
t_bar_snr = 1:binWidth_snr:length(spk_snr);
psth_snr = zeros(1,length(t_bar_snr));

for psth_j = 1:length(t_bar_snr)-1
psth_snr(psth_j) = sum(sum(spk_snr(:,t_bar_snr(psth_j):(t_bar_snr(psth_j)+binWidth_snr-1))));
end

subplot(5,1,5)
bar(t_bar_snr*0.0001,psth_snr/(size(spk_snr,1)*(binWidth_snr*0.0001)))
xlim([0 length(spk_gp)*0.0001])
ylabel('snr PSTH (spikes/s)')

% %%
plot(mean(Isyn_gp,1))


figure
plot(Isnr)

figure
plot(fr_gp)

% %% [markdown]
% GP cells are inhibited and SNr cells disinhibited at 60% activation

% %% [markdown]
% Next, in order to find the threshold, I test the values between 50% and 60%.

% %%
% Monte Carlo
spk_gp=[];
spk_snr=[];
spk_str=[];
for l = 1:10
%%Simulation
[Vm_gp,Vm_snr,Vm_str] = BGdelayline('stimCellsPer',54);

spk_gp = [spk_gp; Vm_gp==15];
spk_snr = [spk_snr; Vm_snr==15];
spk_str = [spk_str; Vm_str==15];
end



%%Plot
figure
subplot(3,1,1)
plotRaster(spk_str);
title('Spike rater plots (5pA)')
ylabel('Str cells')
subplot(3,1,2)

plotRaster(spk_gp);
ylabel('GP cells')
subplot(3,1,3)

plotRaster(spk_snr);
ylabel('SNr cell')
% Out:
% Elapsed time is 0.454188 seconds.
% Elapsed time is 0.472134 seconds.
% Elapsed time is 0.473181 seconds.
% Elapsed time is 0.486812 seconds.
% Elapsed time is 0.477924 seconds.
% Elapsed time is 0.492158 seconds.
% Elapsed time is 0.469330 seconds.
% Elapsed time is 0.459361 seconds.
% Elapsed time is 0.453222 seconds.
% Elapsed time is 0.448405 seconds.

% %% [markdown]
% The threshold of Str activation is ~54%.

% %% [markdown]
% ## Does the amount of Str activation change the latency of SNr firing?

% %% [markdown]
% I will compare the onset of increase in SNr firing while changing the percentage of Str cell activation from 60 to 100, in increments of 10. ( 5 conditions)

% %%
testRange = 10*(6:10);

for test_i = 1:length(testRange)
    spk_gp=[];
    spk_snr=[];
    spk_str=[];
    for l = 1:10
    %%Simulation
        [Vm_gp,Vm_snr,Vm_str] = BGdelayline('stimCellsPer',testRange(test_i));

        spk_gp  = [spk_gp; Vm_gp==15];
        spk_snr = [spk_snr; Vm_snr==15];
        spk_str = [spk_str; Vm_str==15];
    end

    %%Plot
    figure(test_i)
    subplot(3,1,1)
    plotRaster(spk_str);
    title(sprintf('Spike rater plots (5pA),%d percent',testRange(test_i)))
    ylabel('Str cells')
    subplot(3,1,2)

    plotRaster(spk_gp);
    ylabel('GP cells')
    subplot(3,1,3)

    plotRaster(spk_snr);
    ylabel('SNr cell')
    hold on
end
% Out:
% Elapsed time is 0.453124 seconds.
% Elapsed time is 0.483540 seconds.
% Elapsed time is 0.484548 seconds.
% Elapsed time is 0.468993 seconds.
% Elapsed time is 0.504241 seconds.
% Elapsed time is 0.471451 seconds.
% Elapsed time is 0.464378 seconds.
% Elapsed time is 0.447930 seconds.
% Elapsed time is 0.446470 seconds.
% Elapsed time is 0.447296 seconds.
% Elapsed time is 0.453204 seconds.
% Elapsed time is 0.455748 seconds.
% Elapsed time is 0.503945 seconds.
% Elapsed time is 0.478187 seconds.
% Elapsed time is 0.471730 seconds.
% Elapsed time is 0.455636 seconds.
% Elapsed time is 0.455640 seconds.
% Elapsed time is 0.452285 seconds.
% Elapsed time is 0.511952 seconds.
% Elapsed time is 0.470195 seconds.
% Elapsed time is 0.453485 seconds.
% Elapsed time is 0.458650 seconds.
% Elapsed time is 0.449906 seconds.
% Elapsed time is 0.453215 seconds.
% Elapsed time is 0.449954 seconds.
% Elapsed time is 0.452309 seconds.
% Elapsed time is 0.451457 seconds.
% Elapsed time is 0.453101 seconds.
% Elapsed time is 0.481554 seconds.
% Elapsed time is 0.495236 seconds.
% Elapsed time is 0.488180 seconds.
% Elapsed time is 0.514667 seconds.
% Elapsed time is 0.508441 seconds.
% Elapsed time is 0.469021 seconds.
% Elapsed time is 0.507497 seconds.
% Elapsed time is 0.481901 seconds.
% Elapsed time is 0.459573 seconds.
% Elapsed time is 0.458367 seconds.
% Elapsed time is 0.454298 seconds.
% Elapsed time is 0.452870 seconds.
% Elapsed time is 0.455513 seconds.
% Elapsed time is 0.455137 seconds.
% Elapsed time is 0.460379 seconds.
% Elapsed time is 0.468279 seconds.
% Elapsed time is 0.468139 seconds.
% Elapsed time is 0.458734 seconds.
% Elapsed time is 0.465371 seconds.
% Elapsed time is 0.463372 seconds.
% Elapsed time is 0.456469 seconds.
% Elapsed time is 0.452932 seconds.

% %% [markdown]
% The latency for all conditions is roughly 6s, which is 1s after Str stimulation (at 5s)
