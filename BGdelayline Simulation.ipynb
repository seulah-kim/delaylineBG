% %% [markdown]
% Probability of synaptic transmission is set tp 35% and unitary conductance is 100pS

% %%
[Vm_gp,Vm_snr,Vm_str,Isyn_gp_out,Isyn_snr_out] = BGdelayline('n',100);
run('plotBGdelayline.m')
% Out:
% Elapsed time is 0.538402 seconds.
% ...
% > In legend>set_children_and_strings (line 674)
%   In legend>make_legend (line 346)
%   In legend (line 294)
%   In plotBGdelayline (line 26)
%   In run (line 86)

% %% [markdown]
% GP stops firing, but SNr is quiescent. Therefore, I increase constant excitatory input to SNr from 70 to 100.

% %%
[Vm_gp,Vm_snr,Vm_str,Isyn_gp_out,Isyn_snr_out] = BGdelayline('n',100);
run('plotBGdelayline.m')
% Out:
% Elapsed time is 0.463242 seconds.
% ...
% > In legend>set_children_and_strings (line 674)
%   In legend>make_legend (line 346)
%   In legend (line 294)
%   In plotBGdelayline (line 26)
%   In run (line 86)

% %% [markdown]
% Still SNr excitatory input is not strong enough to overcome inhibition from GP cells. Hence, the E_in is increased to 125.

% %%
[Vm_gp,Vm_snr,Vm_str,Isyn_gp_out,Isyn_snr_out] = BGdelayline('n',100);
run('plotBGdelayline.m')
% Out:
% Elapsed time is 0.441486 seconds.
% ...
% > In legend>set_children_and_strings (line 674)
%   In legend>make_legend (line 346)
%   In legend (line 294)
%   In plotBGdelayline (line 26)
%   In run (line 86)
